# %%
import os
from tavily import TavilyClient 
from dotenv import find_dotenv, load_dotenv

_ = load_dotenv(find_dotenv())

# %%
TAVILY_API_KEY = os.environ.get("TAVILY_API_KEY")
client = TavilyClient(api_key=TAVILY_API_KEY)

# %%
result = client.search("What is LangGraph", include_answer=True)

# %%
result["answer"]
# Out:
# 'LangGraph is a versatile tool for building stateful, multi-actor applications with Large Language Models (LLMs). It introduces the concepts of state schemas and reducers for efficient state management. LangGraph is an open-source project focused on providing superior performance and efficiency compared to existing deep learning frameworks, particularly for training and deploying large language models.'

# %%
city = 'San Francisco'
query = f"""How is the current weather in {city} Should go outside for a picnic?"""

# %%
import re
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS

ddg = DDGS()

def search(query, max_results=3):
    results = ddg.text(query, max_results=max_results)
    return [i["href"] for i in results]

for i in search(query):
    print(i)
# Out:
# https://offthegrid.com/blog/13_best_picnic_spots_san_francisco/
# https://secretsanfrancisco.com/best-picnic-spots-sf/
# https://www.accuweather.com/en/us/san-francisco/94103/weather-forecast/6-347629_1_al

# %%
# The old data scraping way

def scrape_weather_info(url):
    """Scrape content from the given URL"""
    if not url:
        return "Weather information could not be found"
    
    # Fetch data
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the webpage"
    
    # Parse results
    soup = BeautifulSoup(response.text, "html.parser")
    return soup

# %%
url = search(query)[0]
soup = scrape_weather_info(url)
print(f"Website: {url}\n\n")
print(soup)
# Out:
# Website: https://www.accuweather.com/en/us/san-francisco/94103/current-weather/347629
#
#
#
# <!DOCTYPE html>
#
# <html class="accuweather" lang="en-us">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8">
# <link href="https://www.accuweather.com/en/us/san-francisco/94103/current-weather/347629" rel="canonical"/>
# <title>San Francisco, CA Current Weather | AccuWeather</title>
# <meta content="Current weather in San Francisco, CA. Check current conditions in San Francisco, CA with radar, hourly, and more." name="Description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="origin" name="referrer"/>
# <meta content="AccuWeather" property="fb:profile_id"/>
# <meta content="132437483467956" property="fb:app_id"/>
# <meta content="71781612888" property="fb:pages"/>
# <meta content="website" property="og:type"/>
# <meta content="San Francisco, CA Current Weather | AccuWeather" property="og:title"/>
# <meta content="Current weather in San Francisco, CA. Check current conditions in San Francisco, CA with radar, hourly, and more." property="og:description"/>
# <meta content="AccuWeather" property="site_name"/>
# <meta content="https://www.accuweather.com/en/us/san-francisco/94103/current-weather/347629" property="og:url"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:url"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:secure_url"/>
# <meta content="https://twitter.com/accuweather" name="twitter:site"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="San Francisco, CA Current Weather | AccuWeather" name="twitter:text:title"/>
# <meta content="San Francisco, CA Current Weather | AccuWeather" name="twitter:title"/>
# <meta content="Current weather in San Francisco, CA. Check current conditions in San Francisco, CA with radar, hourly, and more." name="twitter:description"/>
# <meta content="https://twitter.com/accuweather" name="twitter:site:id"/>
# <meta content="https://twitter.com/accuweather" name="twitter:creator"/>
# <meta content="https://twitter.com/accuweather" name="twitter:creator:id"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" name="twitter:image"/>
# <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:iphone"/>
# <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:iphone"/>
# <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:iphone"/>
# <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:ipad"/>
# <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:ipad"/>
# <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:ipad"/>
# <meta content="AccuWeather Winter weather alerts &amp; forecast radar" name="twitter:app:name:googleplay"/>
# <meta content="com.accuweather.android" name="twitter:app:id:googleplay"/>
# <meta content="https://play.google.com/store/apps/details?id=com.accuweather.android" name="twitter:app:url:googleplay"/>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org",
# 	"@type": "Organization",
# 	"name": "AccuWeather",
# 	"url": "https://www.accuweather.com",
# 	"sameAs": [
# 		"https://www.facebook.com/AccuWeather",
# 		"https://twitter.com/BreakingWeather",
# 		"https://www.instagram.com/accuweather",
# 		"https://www.youtube.com/user/accuweather"
#   ]
# }
# </script>
# <script type="application/ld+json">
# 	{
# 		"@context": "https://schema.org",
# 		"@type": "Place",
# 		"address": {
# 			"@type": "PostalAddress",
# 			"addressLocality": "San Francisco, United States",
# 			"addressRegion": "California",
# 			"postalCode": "94103"
# 		},
# 		"geo": {
# 			"@type": "GeoCoordinates",
# 			"latitude": "37.775",
# 			"longitude": "-122.419",
# 			"addressCountry": "US",
# 			"postalCode": "94103"
# 		},
# 		"name": "San Francisco, California, United States"
# 	}
# 	</script>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org",
# 	"@type": "WebSite",
# 	"mainEntityOfPage": {
# 		"@type": "WebPage",
# 		"@id": "https://www.accuweather.com/en/us/san-francisco/94103/current-weather/347629",
# 		"relatedLink": "https://www.accuweather.com/en/us/san-francisco/94103/current-weather/347629"
# 	},
# 	"image": {
# 		"@type": "ImageObject",
# 		"url": "https://www.accuweather.com/images/logos/accuweather-dark.png",
# 		"height": 172,
# 		"width": 1200
# 	},
# 	"author": {
# 		"@type": "Person",
# 		"name": "AccuWeather"
# 	},
# 	"publisher": {
# 		"@context": "https://schema.org",
# 		"@type": "Organization",
# 		"name": "AccuWeather",
# 		"url": "https://www.accuweather.com/",
# 		"logo": {
# 			"@type": "ImageObject",
# 			"url": "https://www.accuweather.com/images/logos/accuweather-dark-small.png",
# 			"width": 163,
# 			"height": 23
# 		}
# 	},
# 	"url": "https://www.accuweather.com/en/us/san-francisco/94103/current-weather/347629",
# 	"headline": "San Francisco, CA Current Weather",
# 	"description": "Current weather in San Francisco, CA. Check current conditions in San Francisco, CA with radar, hourly, and more."
# }
# </script>
# <style>
# 		@font-face {
# 			font-family: 'Solis';
# 			src: url('/fonts/Solis-Regular.woff2') format('woff2');
# 			font-weight: 400;
# 			font-style: normal;
# 			font-display: swap;
# 		}
# 	</style>
# <style>
# 			:root {
# 				--bg: #1f1f1f;
# 				--header-bg: #1f1f1f;
# 				--header-bg-top: #1f1f1f;
# 			}
# 		</style>
# <script>
# 	 var globalAdConfig = {"prebidTimeout":1000,"awxTimeout":1000,"ortbSite":{"categories":["IAB3","IAB7","IAB8","IAB10","IAB12","IAB15","IAB17","IAB20","150","210","223","274","286","464","483","552","653"],"content":{"title":"","url":"","categories":["IAB12-3","IAB15-10","IAB20-8","390","660"],"productQuality":"1","context":"5","keywords":"","sourceRelationship":1,"language":"","data":{"name":"accuweather.com","extensions":{"segtax":"4"},"segments":[{"name":"id","value":"390"},{"name":"id","value":"660"}]}},"domain":"www.accuweather.com","keywords":"","name":"AccuWeather","privacyPolicy":1,"mobile":1,"pageCategories":["IAB12-3","IAB15-10","IAB20-8","390","660"],"publisher":{"name":"AccuWeather","domain":"www.accuweather.com","categories":["IAB3","IAB7","IAB8","IAB10","IAB12","IAB15","IAB17","IAB20","150","210","223","274","286","464","483","552","653"]},"sectionCategories":[""]},"enableSingleRequest":true,"lazyLoadingData":"{}","skipGoogleAdManager":true,"prebidBundleId":"b","testVariant":"","disableInitialAdLoad":true,"javascriptHead":"","javascriptBody":""};
# 		 (['segtax']).forEach((key) => {if(globalAdConfig.ortbSite.content.data.extensions?.[key]){ globalAdConfig.ortbSite.content.data.extensions[key] = parseInt(globalAdConfig.ortbSite.content.data.extensions[key]) }})
# var isPrebidDisabled = true;
# var adExclusion = null;
# var botDetected = 1;
# var adInfo = {"fdate":"20240606","lang":"en-us","ut":"1","advelvet":"18","bot":"1, Unknown Bot (B8E4201CA3B8EDF5DEAEE8E277BFB3CD):monitor:Browser Impersonator","pgview":"1","partner":"accuweather","ufdb":"SFOC","city":"San Francisco","country":"US","state":"CA","dma":"807","key":"347629","zip":"941XX","browser":"other","connection":"_vhigh_5000","wx_seg":"101105100,101101104,100109104,104100104,100112103,108102100,100111101,101104101,110100100,109101100,102101100,102102100,108105100,101103100,102100100,108103102,100108101,101108100,102103102,100113105,100109107,100100,101102101,101106101,100106103,110101102,109105103,109104103,101100100,108100104,101107100,109102104,103100104,109106104,108101104,107100103,999100001,102104100,105100104,109103104,104101104,103101104,107101103,109100104,108104101","alertscategory":"NON-PRECIPITATION","alertssource":"US","alertstypeid":"US12","cuhd":"69","cuhi":"61","cuuv":"8","cuwd":"6","cuwx":"3","realfeel":"70,a70","fc1hi":"65","fc1lo":"55","fc1wx":"2","lfscategory":"fog","lfsday":"2","lfsseverity":"5","lfs":"5_fog_2","pt":"0","userid":"active","userid3p":"active","iabctax":"IAB12-3,IAB15-10,IAB20-8,390,660"};
#
# // page views
# var awPageViewName = 'awx_pv';
# var pageViewItem = JSON.parse(window.localStorage.getItem(awPageViewName));
# if (!pageViewItem) {
# 	pageViewItem = {val: 1}
# }
# var currentTime = new Date();
# var midnight = new Date();
# var pageViewCount = 1;
# midnight.setDate(midnight.getDate() + 1);
# midnight.setHours(0, 0, 0, 0);
# if (currentTime < pageViewItem.ttl) {
# 	pageViewCount = parseInt(pageViewItem.val ?? 0) + 1;
# }
# window.adInfo = window.adInfo || {};
# window.adInfo.pgview = pageViewCount.toString();
# window.localStorage.setItem(awPageViewName, JSON.stringify({
# 	val: pageViewCount,
# 	ttl: Date.now() + Math.abs(midnight.getTime() - currentTime.getTime())
# }));
#
# var adPageInfo = {category:'weather',template:'current'};
# var partnerCode = 'accuweather';
# var countryCode = 'us';
# var networkType = 'Unknown';
# var throughput = 'vhigh';
# </script>
# <script>
# 		var serverAdsOnPageLite = {"top":{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"google","params":{"sizes":"970x250,728x90,fluid","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":29838031,"allowSmallerSizes":"FALSE","keywords":{"fdate":["20240606"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["SFOC"],"country":["US"],"state":["CA"],"dma":["807"],"wx_seg":["101105100","101101104","100109104","104100104","100112103","108102100","100111101","101104101","110100100","109101100","102101100","102102100","108105100","101103100","102100100","108103102","100108101","101108100","102103102","100113105","100109107","100100","101102101","101106101","100106103","110101102","109105103","109104103","101100100","108100104","101107100","109102104","103100104","109106104","108101104","107100103","999100001","102104100","105100104","109103104","104101104","103101104","107101103","109100104","108104101"],"alertscategory":["NON-PRECIPITATION"],"alertssource":["US"],"alertstypeid":["US12"],"cuhd":["69"],"cuhi":["61"],"cuuv":["8"],"cuwd":["6"],"cuwx":["3"],"realfeel":["70","a70"],"fc1hi":["65"],"fc1lo":["55"],"fc1wx":["2"],"lfscategory":["fog"],"lfsday":["2"],"lfsseverity":["5"],"lfs":["5_fog_2"],"pt":["0"],"adunit":["/6581/web/us/top/weather/current"]},"reserve":2.0,"position":"above","supplyType":"web","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"rubicon","params":{"accountId":12562,"siteId":135890,"zoneId":2841914,"position":"atf","userId":"65b9d07aa1864460b4887063841b629f","floor":2.0,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode":"Acccuweather_Prebid_web_top_highperformance_970x250","floor":2.0,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"pubmatic","params":{"publisherId":"34576","adSlot":"Web_Top","lat":"37.78","lon":"-122.42","kadfloor":"2.00","currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"grid","params":{"uid":6028,"keywords":{"fdate":["20240606"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["SFOC"],"country":["US"],"state":["CA"],"dma":["807"],"wx_seg":["101105100","101101104","100109104","104100104","100112103","108102100","100111101","101104101","110100100","109101100","102101100","102102100","108105100","101103100","102100100","108103102","100108101","101108100","102103102","100113105","100109107","100100","101102101","101106101","100106103","110101102","109105103","109104103","101100100","108100104","101107100","109102104","103100104","109106104","108101104","107100103","999100001","102104100","105100104","109103104","104101104","103101104","107101103","109100104","108104101"],"alertscategory":["NON-PRECIPITATION"],"alertssource":["US"],"alertstypeid":["US12"],"cuhd":["69"],"cuhi":["61"],"cuuv":["8"],"cuwd":["6"],"cuwx":["3"],"realfeel":["70","a70"],"fc1hi":["65"],"fc1lo":["55"],"fc1wx":["2"],"lfscategory":["fog"],"lfsday":["2"],"lfsseverity":["5"],"lfs":["5_fog_2"],"pt":["0"],"adunit":["/6581/web/us/top/weather/current"]},"bidFloor":2.0,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"yahoossp","params":{"dcn":"8a9691d3017474551cc955a9acbd0027","pos":"web_hb_top_1","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":"974818","bidFloor":2.0,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"openx","params":{"delDomain":"accuweather-d.openx.net","unit":"539580665","customParams":{"fdate":["20240606"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["SFOC"],"country":["US"],"state":["CA"],"dma":["807"],"wx_seg":["101105100","101101104","100109104","104100104","100112103","108102100","100111101","10110410 ...
# 		var fcConsentCookie = '';
# 		var USPString = '1YNN';
#
# 		try {
# 			;
# 		} catch (error) {}
#
# 		// A map object that stores all ads on page in order where key is the div id and value is the ad object
# 		var pageHasRepeatAds = false;
# 		var adsOnPage = new Map();
# 		const order = ["top","top_right","infeed","bottom_right","middle","native","bottom","oop","interstitial"];
# 		const orderedAds = Object.keys(window.serverAdsOnPageLite)
# 			.sort((a, b) => order.indexOf(a.split('-')[0]) - order.indexOf(b.split('-')[0]))
# 			.filter((adDivId) => order.indexOf(adDivId.split('-')[0]) > -1);
# 		orderedAds.forEach((adId) => {
# 			const adObject = window.serverAdsOnPageLite[adId];
# 			adObject.winner = { auction: 0 };
# 			const strippedId = adId.split('-')[0];
# 			// Mark repeating ad units
# 			if (adsOnPage.has(strippedId)) {
# 				adObject.isRepeat = true;
# 				window.serverAdsOnPageLite[strippedId].isRepeat = true;
# 				window.pageHasRepeatAds = true;
# 			}
# 			adsOnPage.set(adId, adObject)
# 		});
#
# 		// Parse lazy loading config
# 		if (window.globalAdConfig?.lazyLoadingData) {
# 			let lazyLoadData;
# 			try {
# 				lazyLoadData = JSON.parse(window.globalAdConfig.lazyLoadingData.replace(/(['"])?([a-z0-9A-Z_]+)(['"])?:/g, '"$2": '));
# 			} catch (error) {}
# 			if (typeof lazyLoadData === 'object' && Object.keys(lazyLoadData).length > 0) {
# 				window.globalAdConfig.lazyLoadingData = lazyLoadData;
# 			} else {
# 				window.globalAdConfig.lazyLoadingData = null;
# 			}
# 		}
# 	</script>
# <script>
# 	var gaAppConfig = {
#   "snowfallMap": true,
#   "mapCta": true,
#   "iceChart": true,
#   "winterOutlookCard": true,
#   "winterUpcomingCard": true,
#   "impactedCities": true,
#   "tempWindChart": true,
#   "snowfallChart": true,
#   "postEventCta": true,
#   "winterCenterMap": true
# };
# 	var userCookie = {"cDate":"2024-06-06","isDarkMapStyle":false,"lang":"en-us","rl":["347629"],"tp":"C","ccb":true,"userContentAffinity":{}};
# 	var recentLocations = [{"adminArea":{"englishName":"California","id":"CA","localizedName":"California"},"alertCount":0,"country":{"englishName":"United States","id":"US","localizedName":"United States"},"icon":3,"key":"347629","localizedName":"San Francisco","postalCode":"94103","temp":"15°","realFeel":"20°","isDayTime":true}];
# 	var currentLocation = {"plumeLabsLink":"https://air.plumelabs.com/air-quality-in-san-francisco-ca-mCH5","dma":{"englishName":"San Francisco-Oakland-San Jose, CA","id":"807","localizedName":"San Francisco-Oakland-San Jose, CA"},"englishName":"San Francisco","gmtOffset":-7.0,"hasAlerts":true,"hasForecastConfidence":true,"hasPollen":true,"hasMinuteCast":true,"hasFutureRadar":true,"lat":37.775,"lon":-122.419,"mediaRegion":"SW","region":{"englishName":"North America","id":"NAM","localizedName":"North America"},"timeZone":"PDT","timeZoneCode":"PDT","administrativeArea":{"englishName":"California","id":"CA","localizedName":"California"},"country":{"englishName":"United States","id":"US","localizedName":"United States"},"key":"347629","localizedName":"San Francisco","primaryPostalCode":"94103","source":"AccuWeather"};
# 	var serverAdsOnPage = [{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"google","params":{"sizes":"970x250,728x90,fluid","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":29838031,"allowSmallerSizes":"FALSE","keywords":{"fdate":["20240606"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["SFOC"],"country":["US"],"state":["CA"],"dma":["807"],"wx_seg":["101105100","101101104","100109104","104100104","100112103","108102100","100111101","101104101","110100100","109101100","102101100","102102100","108105100","101103100","102100100","108103102","100108101","101108100","102103102","100113105","100109107","100100","101102101","101106101","100106103","110101102","109105103","109104103","101100100","108100104","101107100","109102104","103100104","109106104","108101104","107100103","999100001","102104100","105100104","109103104","104101104","103101104","107101103","109100104","108104101"],"alertscategory":["NON-PRECIPITATION"],"alertssource":["US"],"alertstypeid":["US12"],"cuhd":["69"],"cuhi":["61"],"cuuv":["8"],"cuwd":["6"],"cuwx":["3"],"realfeel":["70","a70"],"fc1hi":["65"],"fc1lo":["55"],"fc1wx":["2"],"lfscategory":["fog"],"lfsday":["2"],"lfsseverity":["5"],"lfs":["5_fog_2"],"pt":["0"],"adunit":["/6581/web/us/top/weather/current"]},"reserve":2.0,"position":"above","supplyType":"web","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"rubicon","params":{"accountId":12562,"siteId":135890,"zoneId":2841914,"position":"atf","userId":"65b9d07aa1864460b4887063841b629f","floor":2.0,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode":"Acccuweather_Prebid_web_top_highperformance_970x250","floor":2.0,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"pubmatic","params":{"publisherId":"34576","adSlot":"Web_Top","lat":"37.78","lon":"-122.42","kadfloor":"2.00","currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"grid","params":{"uid":6028,"keywords":{"fdate":["20240606"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["SFOC"],"country":["US"],"state":["CA"],"dma":["807"],"wx_seg":["101105100","101101104","100109104","104100104","100112103","108102100","100111101","101104101","110100100","109101100","102101100","102102100","108105100","101103100","102100100","108103102","100108101","101108100","102103102","100113105","100109107","100100","101102101","101106101","100106103","110101102","109105103","109104103","101100100","108100104","101107100","109102104","103100104","109106104","108101104","107100103","999100001","102104100","105100104","109103104","104101104","103101104","107101103","109100104","108104101"],"alertscategory":["NON-PRECIPITATION"],"alertssource":["US"],"alertstypeid":["US12"],"cuhd":["69"],"cuhi":["61"],"cuuv":["8"],"cuwd":["6"],"cuwx":["3"],"realfeel":["70","a70"],"fc1hi":["65"],"fc1lo":["55"],"fc1wx":["2"],"lfscategory":["fog"],"lfsday":["2"],"lfsseverity":["5"],"lfs":["5_fog_2"],"pt":["0"],"adunit":["/6581/web/us/top/weather/current"]},"bidFloor":2.0,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"yahoossp","params":{"dcn":"8a9691d3017474551cc955a9acbd0027","pos":"web_hb_top_1","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":"974818","bidFloor":2.0,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"openx","params":{"delDomain":"accuweather-d.openx.net","unit":"539580665","customParams":{"fdate":["20240606"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["SFOC"],"country":["US"],"state":["CA"],"dma":["807"],"wx_seg":["101105100","101101104","100109104","104100104","100112103","108102100","100111101","101104101","1101001 ...
# 	var weatherEvents = [];
# 	var userData = {"city":"BANGALORE","continent":1,"countryCode":"IN","county":"","lat":12.98,"lon":77.58,"regionCode":"KA","throughput":"vhigh","bw":"5000","networkType":"","zipCodes":[{"primary":""}],"device":{"browserVersion":""}};
# 	var isUserCountryEEA = false;
# 	var showPrivacyPolicyBanner = true;
# 	var mapbox={token:'pk.eyJ1IjoiYWNjdXdlYXRoZXItaW5jIiwiYSI6ImNqeGtxeDc4ZDAyY2czcnA0Ym9ubzh0MTAifQ.HjSuXwG2bI05yFYmc0c9lw',style:'mapbox://styles/accuweather-inc/cjknc24na2o5u2sqoy0t8ku8a'};
# 	var dts={token:'de13920f574d420984d3080b1fa6132b'};
# 	setTimeout(function() {
# 		var reg = new RegExp('(\\s|^)' + 'ads-not-loaded' + '(\\s|$)');
# 		if (document.body.hasAttribute('class')) {
# 			document.body.setAttribute('class', document.body.getAttribute('class').replace(reg, ' '));
# 		}
# 	}, 3000);
# </script>
# <script>
# 	var hostEnvironment = 'Production-NEURO-K8S';
# 	var pageId = 'current-weather';
# 	var siteVersion = "2.2.58.0";
# 	var activeFeatureTest = '';
# </script>
# <script type="text/javascript">
# 		var PushlySDK = window.PushlySDK || [];
# 		function pushly() { PushlySDK.push(arguments) }
# 		window.pushlyCallback = function() {
# 			pushly('load', {
# 				domainKey: '16if7iQ5tgH1FcRA4cUeejyVcdf5guIAEV9R',
# 				sw: '/pushly-sdk-worker.js'
# 			});
# 		};
# 	</script>
# <script>const startMetric=Date.now();function measureTiming(t){var e=Date.now()-startMetric;console.log(t+": "+e);window[t]=e}</script>
# <script>window.isUserCountryEEA = false;</script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
# 		window.pbjs = window.pbjs || {};
# 		pbjs.que = pbjs.que || [];
# 		// Initialize ad info
# 		window.measureTiming('AdManager_Initialization');
# 		adInfo['hour'] = new Date().getHours().toString();
# 		const width = document.documentElement.clientWidth;
# 		const height = document.documentElement.clientHeight;
# 		const round = x => Math.ceil(x / 10) * 10;
# 		adInfo['viewport'] = `${round(width)}x${round(height)}`;
# 		adInfo['site'] = width >= 768
# 			? (width >= 1024 ? 'desktop' : 'tablet')
# 			: 'mobile';
# 		// Helper function for uprTargeting
# 		window.uprTargeting = (gptSlot, adObject) => {
#
# 				const uprTargeting = {
# 					upr: adObject.upr,
# 					upr_0: 'no_bid',
# 					upr_auction: 'skipped',
# 					hb_bid_1st: 'no_bid',
# 					hb_bid_2nd: 'no_bid',
# 				};
# 							if (gptSlot) {
# 				Object.keys(uprTargeting).forEach((key) => {
# 					if (uprTargeting[key]) {
# 						gptSlot.setTargeting(key, String(uprTargeting[key]));
# 					}
# 				});
# 			}
# 			return uprTargeting;
# 		};
# 	</script>
# <script>
#
# 				window.prebidBidPromise = Promise.resolve();
# 				window.prebidTimeoutPromise = Promise.resolve();
# 				const buyItNowBids = [];
# 					// Ad results object
# 		const prevAdResults = JSON.parse(localStorage.getItem('adResults'));
# 		if (adInfo.pgview === '1' && prevAdResults) {
# 			prevAdResults.previousRatio = prevAdResults.filledAds / prevAdResults.possibleAds;
# 			prevAdResults.filledAds = 0;
# 			prevAdResults.possibleAds = 0;
# 		}
# 		window.adResults = prevAdResults || {};
#
# 		// Start ad process
# 		window.googletag = window.googletag || { cmd: [] };
# 		googletag.cmd.push(function() {
# 			window.measureTiming('GPT_Initialization');
# 			if (!window.globalAdConfig || window.globalAdConfig.disableInitialAdLoad) {
# 				googletag.pubads().disableInitialLoad();
# 			}
# 			googletag.pubads().enableAsyncRendering();
# 			if (!window.globalAdConfig || window.globalAdConfig.enableSingleRequest) {
# 				googletag.pubads().enableSingleRequest();
# 			}
# 			googletag.pubads().setCentering(true);
# 			googletag.pubads().setSafeFrameConfig({
# 				allowOverlayExpansion: false,
# 				allowPushExpansion: true,
# 				sandbox: true,
# 			});
# 			// Set page level targeting
# 			for (const [key, value] of Object.entries(adInfo)) {
# 				if (value) {
# 					googletag.pubads().setTargeting(key, value);
# 				}
# 			}
# 			// Set privacy settings
# 			if (adInfo.rdp === '1') {
# 				googletag.pubads().setTargeting('optout', 'true');
# 				googletag.pubads().setPrivacySettings({
# 					restrictDataProcessing: true,
# 				});
# 			} else {
# 				googletag.pubads().setTargeting('optout', 'false');
# 			}
# 			// Set ppid targeting
# 			const ppid = '65b9d07aa1864460b4887063841b629f';
# 			if (ppid) {
# 				googletag.pubads().setPublisherProvidedId(ppid);
# 			}
#
# 			// Set location
# 			if (window.userData && window.userData.zipCodes && window.userData.zipCodes.length > 0 && window.userData.countryCode.toLowerCase() === 'us') {
# 				const zip = window.userData.zipCodes[0].primary;
# 				googletag.pubads().setLocation(`${zip},US`);
# 			}
#
# 			// Init ad server
# 			const FAILSAFE_TIMEOUT = (window.globalAdConfig && typeof window.globalAdConfig.awxTimeout === 'number') ? window.globalAdConfig.awxTimeout : 10000;
# 			let IS_ADSERVER_INIT = false;
# 			const initAdserver = () => {
# 				if (IS_ADSERVER_INIT) {
# 					return;
# 				}
# 				IS_ADSERVER_INIT = true;
# 				measureTiming('AdManager_InitAdServer');
# 				// Define ads in order
# 				const order = ["top","top_right","infeed","bottom_right","middle","native","bottom","oop","interstitial"];
# 				const orderedAds = Object.keys(window.serverAdsOnPageLite)
# 					.sort((a, b) => order.indexOf(a.split('-')[0]) - order.indexOf(b.split('-')[0]))
# 					.filter((adDivId) => order.indexOf(adDivId.split('-')[0]) > -1);
# 				const gptSlots = orderedAds.map((adDivId) => {
# 					const adsOnPage = window.serverAdsOnPageLite || {};
# 					const adObject = adsOnPage[adDivId];
# 					if (adObject && document.getElementById(adObject.adDivId)) {
# 						// Check if buy it now bids won
# 						let highestBid = { cpm: 0 };
# 						if (pbjs?.getBidResponsesForAdUnitCode) {
# 							const bidResponses = pbjs.getBidResponsesForAdUnitCode(adObject.adUnitCode);
# 							// Get the BuyItNow bid with highest cpm
# 							bidResponses.bids.forEach((bid) => {
# 								if (buyItNowBids.indexOf(bid.requestId) > -1 && bid.cpm > highestBid.cpm) {
# 									highestBid = bid;
# 								}
# 							});
# 						}
# 						// If BuyItNow is valid, change the ad unit code geo part to bin_prebid
# 						//  - then if skipGoogleAdManager is true, render the creative and create an oop ad unit for DFP tracking
# 						//  - else, return the gptSlot with the new ad code
# 						// otherwise return the gptSlot with the original ad code
# 						let isAdUnitPartOfInitialAuction = true;
# 						if (window.globalAdConfig?.lazyLoadingData && window.pageHasRepeatAds && window.initialAdDivIdsAuction) {
# 							isAdUnitPartOfInitialAuction = window.initialAdDivIdsAuction.includes(adObject.adDivId);
# 						}
# 						if (highestBid.cpm > 0 && isAdUnitPartOfInitialAuction) {
# 							const adCode = adObject.adUnitCode.split('/');
# 							adCode[3] = 'bin_prebid';
# 							adObject.code = adCode.join('/');
# 							// Sets the pug page-level targeting
# 							googletag.pubads().setTargeting('pug', '1');
# 							if (!window.globalAdConfig || window.globalAdConfig.skipGoogleAdManager) {
# 								// Mark winner.auction 1 if a buy it now bid wins
# 								adObject.winner.auction = 1;
#
# 								window.renderPrebidWithIframe(adObject, highestBid);
# 								// Create the bin_prebid tracking slot
# 								const oopId = `${adObject.adDivId}-oop`;
# 								const oopDiv = document.createElement('div');
# 								oopDiv.setAttribute('id', oopId);
# 								oopDiv.setAttribute('class', 'tracking-slot');
# 								document.body.appendChild(oopDiv);
# 								const gptSlot = googletag.defineOutOfPageSlot(adObject.code, oopId);
# 								gptSlot?.addService(googletag.pubads());
# 								Object.keys(highestBid.adserverTargeting).forEach((key) => {
# 									gptSlot.setTargeting(key, highestBid.adserverTargeting[key]);
# 								});
# 								if (window.adInfo) {
# 									if (window.adInfo.partner) {
# 										gptSlot.setTargeting('partner', window.adInfo.partner);
# 									}
# 									gptSlot.setTargeting('userid3p', window.adInfo.userid3p);
# 								}
# 								adObject.gptSlot = gptSlot;
# 								return gptSlot;
# 							}
# 						}
# 						// Get sizes from config
# 						let { sizes = [], responsiveSizes = [] } = adObject.config || {};
# 						let gptSlot;
# 						// If responsiveSizes are defined, use it for sizes
# 						const platform = adObject.adUnitCode.split('/')[2];
# 						responsiveSizes.forEach(respSize => {
# 							// Filter out sizes
# 							if (adObject.adType === 'bottom' && (platform === 'ios' || platform === 'android')) {
# 								respSize.sizes = respSize.sizes.filter(s => s.toString() !== '300,600');
# 							}
#
# 							if (sizes.length === 0 && document.documentElement.clientWidth >= respSize.window[0]) {
# 								sizes = respSize.sizes;
# 							}
# 						});
# 						if (adObject.adType === 'oop') {
# 							gptSlot = googletag.defineOutOfPageSlot(adObject.adUnitCode, adObject.adDivId);
# 						} else if (adObject.adType === 'interstitial') {
# 							gptSlot = googletag.defineOutOfPageSlot(adObject.adUnitCode, googletag.enums.OutOfPageFormat.INTERSTITIAL);
# 						} else {
# 							gptSlot = googletag.defineSlot(adObject.adUnitCode, sizes, adObject.adDivId);
# 						}
# 						if (responsiveSizes && responsiveSizes.length > 0) {
# 							const mapping = googletag.sizeMapping();
# 							responsiveSizes.forEach((mapObject) => {
# 								mapping.addSize(mapObject.window, mapObject.sizes);
# 							});
# 							gptSlot.defineSizeMapping(mapping.build());
# 						}
# 						window.uprTargeting(gptSlot, adObject);
# 						gptSlot?.addService(googletag.pubads());
# 						adObject.gptSlot = gptSlot;
# 						// Only return the gptSlot that's included in initial request
# 						if (adObject.includeInSRA) {
# 							return gptSlot;
# 						}
# 					}
# 					return null;
# 				}).filter((x) => x);
# 				if (window.globalAdConfig?.lazyLoadingData) {
# 					googletag.pubads().enableLazyLoad(window.globalAdConfig.lazyLoadingData);
# 				}
# 				// Enable services when all slots are defined
# 				googletag.enableServices();
# 				// Call display after services are enabled
# 				gptSlots.forEach((gptSlot) => {
# 					const adDivId = gptSlot.getSlotElementId();
# 					window.measureTiming(`AdManager_${adDivId}_Display`);
# 					googletag.display(adDivId);
# 				});
# 				// Renders all ads on page
# 				window.pbjs?.setTargetingForGPTAsync && pbjs.setTargetingForGPTAsync();
# 				window.measureTiming('AdManager_SetTargetingForGPTAsync');
# 				if (!window.globalAdConfig || window.globalAdConfig.disableInitialAdLoad) {
# 					if (window.globalAdConfig && !window.globalAdConfig.enableSingleRequest) {
# 						gptSlots.forEach((gptSlot) => {
# 							googletag.pubads().refresh([gptSlot]);
# 						});
# 					} else {
# 						googletag.pubads().refresh(gptSlots);
# 					}
# 				}
# 			};
#
# 			// If initial ad load is disabled, wait for prebid
# 			if (!window.globalAdConfig || window.globalAdConfig.disableInitialAdLoad) {
# 				// A timeout incase bidding fails or takes too long
# 				setTimeout(initAdserver, FAILSAFE_TIMEOUT);
# 				window.prebidBidPromise.then(initAdserver);
# 			} else {
# 				initAdserver();
# 			}
# 			googletag.pubads().addEventListener('slotRenderEnded', (event) => {
# 				if (document.body.classList.contains('ads-not-loaded')) {
# 					setTimeout(() => document.body.classList.remove('ads-not-loaded'), 750);
# 				}
# 				const adSlot = window.serverAdsOnPageLite[event.slot.getSlotElementId()];
# 				if (adSlot) {
# 					const renderedAdEl = document.getElementById(adSlot.adDivId);
# 					if (renderedAdEl) {
# 						setTimeout(() => {
# 							renderedAdEl.classList.remove('unrendered');
# 						}, 250);
# 					}
# 				}
# 			});
# 			let isInterstitialRendered = false;
# 			googletag.pubads().addEventListener('slotResponseReceived', () => {
# 				if (!isInterstitialRendered && window.serverAdsOnPageLite['interstitial']) {
# 					isInterstitialRendered = true;
# 					const { gptSlot } = window.serverAdsOnPageLite['interstitial'];
# 					if (gptSlot) {
# 						googletag.display(gptSlot.getSlotElementId());
# 						googletag.pubads().refresh([gptSlot]);
# 					}
# 				}
# 			});
# 		});
# 	</script>
# <script>
# function getAwxSession(categories, pageId) {
# 	const AWX_SESSION_NAME = 'awx_session';
# 	const defaultVal = {
# 		categoryFlow: [],
# 		visitFlow: [],
# 		ttl: Date.now() + 600000
# 	};
#
# 	let awxSession = JSON.parse(window.localStorage.getItem(AWX_SESSION_NAME) || '{}');
# 	if (!awxSession.ttl || Date.now() > awxSession.ttl) {
# 		awxSession = defaultVal;
# 	}
#
# 	if (categories) {
# 		categories = categories.toLowerCase().replace(/\s/g, '-');
# 		awxSession.categoryFlow = awxSession.categoryFlow.concat(categories.split('|')).slice(-30);
# 	}
#
# 	if (pageId) {
# 		awxSession.visitFlow.push(pageId);
# 	}
#
# 	try {
# 		window.localStorage.setItem(AWX_SESSION_NAME, JSON.stringify(awxSession));
# 	} catch {};
#
# 	return {
# 		categoryFlow: awxSession.categoryFlow.join('/'),
# 		visitFlow: awxSession.visitFlow.join('/'),
# 		visitFlowArray: awxSession.visitFlow
# 	};
# }
#
# function getUserContentAffinity(categories) {
# 	const storageKey = 'awxContentAffinity';
# 	const storageValue = window.localStorage.getItem(storageKey);
# 	const contentAffinity = (storageValue && storageValue !== '{}') ? JSON.parse(storageValue) : window.userCookie.userContentAffinity;
#
# 	if (categories) {
# 		categories = categories.toLowerCase().replace(/\s/g, '-');
# 		categories.split('|').forEach(function(category) {
# 			contentAffinity[category] = (contentAffinity[category] || 0) + 1;
# 		});
# 	}
#
# 	try {
# 		window.localStorage.setItem(storageKey, JSON.stringify(contentAffinity));
# 	} catch {};
#
# 	return Object.keys(contentAffinity).map(function(category) {
# 		return category + ':' + contentAffinity[category];
# 	}).join('/');
# }
# </script>
# <script>
# 	function getCampaignLongevity() {
# 		var inBrowser = typeof window !== 'undefined';
# 		var hasLocalStorage =
# 			inBrowser &&
# 			'localStorage' in window &&
# 			window.localStorage !== null &&
# 			typeof window.localStorage.setItem === 'function' &&
# 			typeof window.localStorage.getItem === 'function';
#
# 		function getParamByName(name, url) {
# 			if (!url) url = window.location.href;
# 			name = name.replace(/[\[\]]/g, '\\$&');
# 			var regex = new RegExp('[?&]' + name + '(=([^&#]*)|&|#|$)');
# 			var results = regex.exec(url);
# 			if (!results) return null;
# 			if (!results[2]) return '';
# 			return decodeURIComponent(results[2].replace(/\+/g, ' '));
# 		}
#
# 		function getItem(name) {
# 			var value;
#
# 			if (hasLocalStorage) {
# 				try {
# 					value = window.localStorage.getItem(name);
# 				} catch (err) {
# 					console.error('Failed to read from local storage.', err);
# 				}
# 			} else {
# 				value = getCookie(name);
# 			}
#
# 			return value;
# 		};
#
# 		function setItem(name, value) {
# 			var valueAsString =
# 				typeof value === 'string' ? value : JSON.stringify(value);
# 			if (hasLocalStorage) {
# 				try {
# 					window.localStorage.setItem(name, valueAsString);
# 					return true;
# 				} catch (err) {
# 					console.error('Failed to write to local storage.', err);
# 				}
# 			} else {
# 				// Cookie fallback
# 				setCookie(name, valueAsString, 365);
# 			}
# 		};
#
# 		function setCookie(name, value, days) {
# 			var expires = "";
# 			if (days) {
# 				var date = new Date();
# 				date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
# 				expires = "; expires=" + date.toUTCString();
# 			}
# 			document.cookie = name + "=" + (value || "") + expires + "; path=/";
# 		}
#
# 		function getCookie(name) {
# 			var nameEQ = name + "=";
# 			var ca = document.cookie.split(';');
# 			for (var i = 0; i < ca.length; i++) {
# 				var c = ca[i];
# 				while (c.charAt(0) == ' ') c = c.substring(1, c.length);
# 				if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length, c.length);
# 			}
# 			return null;
# 		}
#
# 		var longevityCheckKey = 'utmCampaignCookie';
# 		var localUtmCampaign = getParamByName('utm_campaign');
# 		var longevityCheck = null;
# 		if (!localUtmCampaign) {
# 			return null;
# 		} else {
# 			var today = new Date();
# 			var todayEpoch = today.getTime();
#
# 			var campaignArray =
# 				JSON.parse(getItem(longevityCheckKey)) || [];
# 			var localCampaign = campaignArray.filter(function (x) {
# 				return x.campaign === localUtmCampaign
# 			})[0];
# 			if (localCampaign) {
# 				var diff = todayEpoch - parseInt(localCampaign.dateAdded || 0);
# 				var diffDays = diff / (1000 * 3600 * 24);
# 				if (diffDays < 1) {
# 					diffDays = 0;
# 				}
# 				longevityCheck = diffDays;
# 			} else {
# 				campaignArray.push({
# 					campaign: localUtmCampaign,
# 					dateAdded: todayEpoch,
# 				});
# 				setItem(longevityCheckKey, campaignArray.slice(0, 20));
# 				longevityCheck = 0;
# 			}
# 			return Math.round(longevityCheck);
# 		}
# 	}
# </script>
# <script>
# 			window.dataLayer = window.dataLayer || [];
# 			function gtag() { dataLayer.push(arguments); }
# 		</script>
# <link href="https://www.awxcdn.com/adc-assets/bundles/city.current-weather-desktop.71f3dc648e94ffe53637.css" rel="stylesheet"/>
# <link href="https://www.awxcdn.com/adc-assets/bundles/3155.5bff36856386cdc6b03a.css" rel="stylesheet"/>
# <link href="https://www.awxcdn.com/adc-assets/bundles/8242.9de4e3b90ac95273ddb0.css" rel="stylesheet"/>
# <link href="https://www.awxcdn.com/adc-assets/bundles/legacy-header.b95dc28ff618a8b24d6a.css" rel="stylesheet"/>
# <script>
# 		window.cnx = window.cnx || {};
# 		window.cnx.cmd = window.cnx.cmd || [];
# 	</script>
# </meta></meta></head>
# <body class="current-weather ads-not-loaded has-alerts full-animation rfphrase-disabled">
# <div class="template-root" style="display:none">
# <div class="basic-header has-alerts" style="visibility: hidden;">
# <a class="pwa-top-banner" href="/pwa">
# <svg class="arrow-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#fff" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# 		Go Back
# 	</a>
# <div class="alert-banner-container has-multiple">
# <div class="banner-wrap" id="banner-wrap">
# <div class="alert-banner alert-banner-breaking">
# <a class="" data-gatype="breaking" href="https://www.accuweather.com/en/severe-weather/1-dead-homes-damaged-after-destructive-tornadoes-and-storms-hit-three-states-and-a-dc-suburb/1657107">
# <svg class="icon-breaking-news" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M1.9 13.176l5.912-3.413 1.75 3.031 2.946-6.897L5.062 5l1.75 3.031L.804 11.5A8 8 0 1 1 1.9 13.177z" fill="#FFF" fill-rule="evenodd"></path></svg>
# <span>At least 1 person is dead after tornado sweeps through northern DC suburbs. Click for more</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron right arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron right</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </a>
# </div>
# <div class="alert-banner alert-banner-breaking">
# <a class="" data-gatype="breaking" href="https://www.accuweather.com/en/weather-forecasts/blistering-heat-wave-to-have-interior-west-searing-into-second-week-of-june/1656973">
# <svg class="icon-breaking-news" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M1.9 13.176l5.912-3.413 1.75 3.031 2.946-6.897L5.062 5l1.75 3.031L.804 11.5A8 8 0 1 1 1.9 13.177z" fill="#FFF" fill-rule="evenodd"></path></svg>
# <span>Blistering heat wave to have interior West searing into second week of June</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron right arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron right</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="header-outer">
# <div class="header-inner">
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-.26 1.692-.78 2.147-.521.456-1.237.716-2.083.716h-.26zm-.65 2.797c.878 0 1.626-.162 2.31-.488.683-.325 1.236-.813 1.691-1.496l.553 1.66h2.506v-8.85c0-1.658-.488-2.927-1.464-3.773-.977-.845-2.343-1.268-4.068-1.268h-.325c-1.562 0-2.798.325-3.71.943-.91.65-1.496 1.431-1.756 2.342l2.928 1.204c.163-.456.456-.813.846-1.139.39-.292.944-.455 1.627-.455h.325c.781 0 1.367.195 1.725.553.39.39.553.91.553 1.594v.683h-2.408c-1.985 0-3.481.39-4.523 1.171-1.04.78-1.561 1.822-1.561 3.09v.196c0 1.268.39 2.244 1.17 2.992.782.716 1.888 1.106 3.32 1.106h.26v-.065zm-12.495-11.353c.943 0 1.659.26 2.147.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.196zm2.765 6.93c-.228.487-.553.878-.976 1.138-.423.293-.943.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.26c-1.92 0-3.45.618-4.588 1.887-1.139 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.455 2.668a5.877 5.877 0 0 0 1.27 2.082 5.83 5.83 0 0 0 2.017 1.366c.813.325 1.692.488 2.7.488h.228c1.27 0 2.343-.26 3.254-.748s1.66-1.236 2.213-2.245l-2.864-1.464zM95.76 22.738l3.97-13.76 3.774 13.76h3.026l5.434-18.673V3.84h-3.254l-3.58 13.37-3.513-13.37h-3.58L94.36 17.436 90.878 3.84h-3.416v.227l5.206 18.673h3.091zm-21.312-13.5v8.555c0 1.594.423 2.863 1.301 3.839.879.975 2.018 1.463 3.482 1.463h.358c.813 0 1.561-.162 2.212-.488.684-.325 1.237-.813 1.692-1.43l.553 1.56h2.473v-13.5h-3.286v7.873c-.033.91-.26 1.659-.748 2.244-.489.586-1.14.879-2.018.879h-.325c-.716 0-1.302-.228-1.757-.716-.456-.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>
# <a class="header-city-link" href="/en/us/san-francisco/94103/weather-forecast/347629">
# <h1 class="header-loc">San Francisco, CA</h1>
# <span class="header-temp">15°<span class="unit">C</span></span>
# <svg class="header-weather-icon" data-src="/images/weathericons/3.svg" height="27" viewbox="0 0 288 288" width="27"><g fill="none" fill-rule="evenodd" stroke-width="9.593"><path d="M143.898 21v47.966M0 164.898h47.966M211.722 97.074l33.912-33.912M76.074 97.074 42.162 63.162M42.162 266.634l33.912-33.912M220.356 159.142c-2.666-35.73-29.7-64.861-65.133-70.183-35.433-5.322-69.833 14.581-82.878 47.952-13.045 33.37-1.264 71.327 28.384 91.446" stroke="#FF8700"></path><path d="M239.83 169.695h-7.53a52.763 52.763 0 0 0-92.958 28.78h-9.834c-15.894 0-28.78 12.885-28.78 28.78 0 15.894 12.886 28.779 28.78 28.779h110.323c23.841 0 43.169-19.328 43.169-43.17 0-23.841-19.328-43.17-43.17-43.17Z" stroke="#BABABA"></path></g></svg>
# </a>
# <a class="brand-logo header-partner-logo" href="http://abc7news.com" rel="sponsored" target="_blank">
# <img alt="" data-src="https://vortex.accuweather.com/adc2010/images/branding-partners/abc-kgo-40x43.png" height="27"/>
# </a>
# <div class="pull-right">
# <a class="page-sponsor" href="https://www.gamezop.com/?id=lW3pW3" rel="noopener noreferrer" target="_blank"><img alt="Gamezop.com" height="24" src="https://www.awxcdn.com/adc-assets/images/logos/gamezop.png" width="30"/></a>
# <div class="header-search-bar search-bar">
# <div class="searchbar-inner">
# <svg class="icon-search" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.186 13.554c-3.462 0-6.303-2.869-6.303-6.359C.883 3.681 3.724.837 7.186.837c3.437 0 6.278 2.844 6.278 6.358 0 3.49-2.865 6.359-6.278 6.359zm5.323-1.602a7.176 7.176 0 0 0 1.815-4.757c0-3.968-3.2-7.195-7.138-7.195C3.223 0 0 3.227 0 7.195c0 3.944 3.223 7.171 7.186 7.171a7.058 7.058 0 0 0 4.75-1.84L17.427 18l.573-.55-5.49-5.498z" transform="translate(3 3)"></path></svg>
# <form action="/en/search-locations" class="search-form" method="GET">
# <input autocomplete="off" class="search-input" data-alternative-placeholder="Search" data-placeholder="Address, City or Zip Code" name="query" placeholder="Address, City or Zip Code" type="text"/>
# </form>
# <svg class="clear-icon close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# <div class="search-options">
# <div class="dropdown-legacy left-bar">
# <div class="displayed-item">
# <span>
# 			Location
# 		</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron down</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </div>
# <div class="items">
# <a class="item active" value="/en/search-locations">
# <span>Location</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-news">
# <span>News</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-video">
# <span>Videos</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar-dropdown">
# <div class="use-current-location">
# <svg class="icon-gps gps-icon" height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><g fill="#000" fill-opacity="0.995941" fill-rule="evenodd" id="Symbols" stroke="none" stroke-width="1"><g id="ICONS-/-Menu-/-GPS"><polygon id="Triangle" points="9.44615242 -1.13878407 15.4461524 15.8612159 9.44615242 12.4612159 3.44615242 15.8612159" transform="translate(9.446152, 7.361216) rotate(-330.000000) translate(-9.446152, -7.361216) "></polygon></g></g></svg>
# <span>Use Current Location</span>
# </div>
# <div class="recent-locations-dropdown">
# <div class="recent-title">Recent</div>
# ...
# </a>
# </div>
# </div>
# <div class="footer-content-tablet">
# <div class="footer-content-category">
# <div class="footer-content-category-wrapper">
# <div class="footer-content-category-header">Company</div>
# <div class="footer-category-section">
# <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Proven Superior Accuracy" data-pagetype="corporate" href="https://corporate.accuweather.com/" target="_blank">
# 				Proven Superior Accuracy
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Company" data-gatext="About AccuWeather" data-pagetype="corporate" href="https://corporate.accuweather.com/company/about-us/" target="_blank">
# 				About AccuWeather
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Digital Advertising" data-pagetype="advertising" href="https://advertising.accuweather.com/for-advertising/digital-advertising/" target="_blank">
# 				Digital Advertising
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Careers" data-pagetype="corporate" href="https://corporate.accuweather.com/company/careers/" target="_blank">
# 				Careers
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Press" data-pagetype="corporate" href="https://corporate.accuweather.com/newsroom/press-releases/" target="_blank">
# 				Press
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Contact Us" data-pagetype="corporate" href="/en/contact" target="_blank">
# 				Contact Us
# 			</a>
# </div>
# </div>
# </div>
# <div class="footer-content-category">
# <div class="footer-content-category-wrapper">
# <div class="footer-content-category-header">Products &amp; Services</div>
# <div class="footer-category-section">
# <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="For Business" data-pagetype="business" href="https://afb.accuweather.com/" target="_blank">
# 				For Business
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="For Partners" data-pagetype="partners" href="https://partners.accuweather.com/" target="_blank">
# 				For Partners
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="For Advertising" data-pagetype="advertising" href="https://advertising.accuweather.com/" target="_blank">
# 				For Advertising
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="AccuWeather APIs" data-pagetype="developer" href="https://developer.accuweather.com/" target="_blank">
# 				AccuWeather APIs
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="AccuWeather Connect" data-pagetype="connect" href="https://afb.accuweather.com/accuweather-connect-and-content-syndication" target="_blank">
# 				AccuWeather Connect
# 			</a>
# <span class="footer-category-section-link text">RealFeel® and RealFeel Shade™</span>
# </div>
# </div>
# </div>
# <div class="footer-content-category">
# <div class="footer-content-category-wrapper">
# <div class="footer-content-category-header">Apps &amp; Downloads</div>
# <div class="footer-category-section">
# <a class="footer-category-section-link" data-gacategory="Apps &amp; Downloads" data-gatext="iPhone App" data-pagetype="apple" href="https://go.onelink.me/app/ef253ee1" target="_blank">
# 				iPhone App
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Apps &amp; Downloads" data-gatext="Android App" data-pagetype="android" href="https://go.onelink.me/app/85d14e58" target="_blank">
# 				Android App
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Apps &amp; Downloads" data-gatext="See all Apps &amp; Downloads" data-pagetype="downloads" href="https://7482826.hs-sites.com/premium-plus" target="_blank">
# 				See all Apps &amp; Downloads
# 			</a>
# </div>
# </div>
# </div>
# <div class="footer-content-category">
# <div class="footer-content-category-wrapper">
# <div class="footer-content-category-header">Subscription Services</div>
# <div class="footer-category-section">
# <a class="footer-category-section-link" data-gacategory="Subscription Services" data-gatext="AccuWeather Premium" data-pagetype="premium" href="https://wwwl.accuweather.com/premium_login.php" target="_blank">
# 				AccuWeather Premium
# 			</a>
# <a class="footer-category-section-link" data-gacategory="Subscription Services" data-gatext="AccuWeather Professional" data-pagetype="pro" href="https://wwwl.accuweather.com/pro_login.php" target="_blank">
# 				AccuWeather Professional
# 			</a>
# </div>
# </div>
# </div>
# <div class="footer-content-category">
# <div class="footer-content-category-wrapper">
# <div class="footer-content-category-header">More</div>
# <div class="footer-category-section">
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="AccuWeather Ready" data-pagetype="accuweather-ready" href="/en/accuweather-ready">
# 				AccuWeather Ready
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Business" data-pagetype="content-landing" href="/en/business">
# 				Business
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Health" data-pagetype="content-landing" href="/en/health-wellness">
# 				Health
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Hurricane" data-pagetype="hurricane" href="/en/hurricane">
# 				Hurricane
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Leisure and Recreation" data-pagetype="content-landing" href="/en/leisure-recreation">
# 				Leisure and Recreation
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Severe Weather" data-pagetype="severe-weather" href="/en/us/severe-weather">
# 				Severe Weather
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Space and Astronomy" data-pagetype="content-landing" href="/en/space-news">
# 				Space and Astronomy
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Sports" data-pagetype="content-landing" href="/en/sports">
# 				Sports
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Travel" data-pagetype="content-landing" href="/en/travel">
# 				Travel
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Weather News" data-pagetype="news" href="/en/weather-news">
# 				Weather News
# 			</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Winter Center" data-pagetype="winter-weather" href="/en/us/winter-weather">
# 				Winter Center
# 			</a>
# </div>
# <div class="footer-social footer-social-tablet">
# <a class="social-link" data-gacategory="Downloads" data-galink="https://downloads.accuweather.com/" data-gatype="outbound" href="https://downloads.accuweather.com/" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/downloads.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="evenodd"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#EE5723"></path><path d="M12.88 12.947a7.243 7.243 0 0 1 10.24 0c2.813 2.826 2.827 7.413 0 10.226-2.827 2.827-7.413 2.827-10.227 0-2.826-2.813-2.826-7.4-.013-10.226ZM18 9.907c-4.467 0-8.107 3.64-8.107 8.106 0 4.467 3.64 8.107 8.107 8.107 4.467 0 8.107-3.64 8.107-8.107 0-4.48-3.64-8.106-8.107-8.106Zm10.12 2.213-3.52-.76-.773-3.507L20.4 8.947l-2.427-2.654L15.56 8.96l-3.427-1.08-.76 3.52-3.506.773L8.973 15.6 6.32 18.027l2.667 2.413-1.08 3.427 3.52.76.773 3.506 3.427-1.093 2.426 2.653 2.414-2.666 3.426 1.08.76-3.52 3.507-.787-1.107-3.427 2.654-2.426-2.667-2.414 1.08-3.413Z" fill="#FFF"></path></g></svg>
# </a>
# <a class="social-link" data-gacategory="Facebook" data-galink="https://www.facebook.com/AccuWeather" data-gatype="social" href="https://www.facebook.com/AccuWeather" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/facebook.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M20.8 5.069c-9.946 0-11.514 4.3-11.514 14.247 0 8.092-1.997 5.082 5.346 7.352C16.315 27.188 16.145 36 18 36c1.72 0 3.383-.24 4.957-.69 2.408-.688 4.466-4.135 6.173-10.342 1.644-2.179 2.466-4.696 2.466-7.55 0-9.947-.85-12.35-10.796-12.35Z" fill="#FFF"></path><path d="M18 0C8.053 0 0 8.053 0 18c0 9.893 7.987 17.933 17.867 18V23.653h-4.16V18.84h4.16v-3.547c0-4.12 2.52-6.36 6.186-6.36 1.76 0 3.267.134 3.707.187v4.307h-2.547c-2 0-2.386.946-2.386 2.346v3.067H27.6l-.627 4.813h-4.146v11.694C30.427 33.227 36 26.267 36 18c0-9.947-8.053-18-18-18Z" fill="#4167B2"></path></g></svg>
# </a>
# <a class="social-link" data-gacategory="Twitter" data-galink="https://twitter.com/BreakingWeather" data-gatype="social" href="https://twitter.com/BreakingWeather" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/twitter.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3"></path><path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF"></path></g></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span>
# <div class="footer-legalese">
# <div class="footer-copyright">
# <span>
# 			© 2024 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
#
# 		</span>
# </div>
# <div class="footer-terms" id="footer-terms">
# <a data-ga="Terms of Use" href="/en/legal" target="_blank">
# 			Terms of Use
# 		</a>
# 		|
# 		<a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
# 			Privacy Policy
# 		</a>
# 		|
# 		<a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
# 			Cookie Policy
# 		</a>
# </div>
# </div>
# </div>
# <div class="privacy-policy-banner" data-banner-delay="0" data-banner-order="0" id="privacy-policy-banner">
# <div class="banner-body">
# <p>
# 				We have updated our <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">Privacy Policy</a> and <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">Cookie Policy</a>.
# 			</p>
# <div class="banner-button policy-accept">I Understand</div>
# </div>
# </div>
# <div class="pushly-prompt-custom" data-banner-delay="500" data-banner-order="1" id="pushly-prompt-custom" style="display: none;">
# <div class="banner-body">
# <div>
# <p>Get AccuWeather alerts as they happen with our browser notifications.</p>
# </div>
# <div>
# <button class="pushly-prompt-buttons-allow banner-enable-button">Enable Notifications</button>
# </div>
# <button class="pushly-prompt-buttons-dismiss banner-dismiss-button">No, Thanks</button>
# </div>
# </div>
# <div class="pushly-banner enabled-banner pushly-prompt-custom" id="pushly-enabled-banner" style="display: none;">
# <div class="banner-body">
# <p class="title">
# <span class="checkmark-wrapper">
# <svg alt="" class="icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </span>
# 			Notifications Enabled
# 		</p>
# <p>
# 			Thanks! We’ll keep you informed.
# 		</p>
# </div>
# </div>
# </div>
# <script>
# 		// Check for third party cookie support
# 		const thirdPartyIframe = document.createElement('iframe');
# 		thirdPartyIframe.setAttribute(
# 			'src',
# 			'https://www.awxcdn.com/adc/3rdpartycheck.html'
# 		);
# 		thirdPartyIframe.setAttribute('style', 'width:0;height:0;display:none');
# 		document.body.appendChild(thirdPartyIframe);
# 	</script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/city.current-weather-desktop.4881b03ef4186ced7c3e.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/4488.a937c9ec499b7a907d8a.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/8411.db12ef87485231b2e012.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/legacy-header.3f0a52ca1578b1e543c8.js"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/gampad/adx?iu=/6581/web/us/video_player/weather/current&amp;sz=3x3&amp;c=638532929479252947&amp;m=text/javascript&amp;t=fdate%3d20240606%26lang%3den-us%26ut%3d1%26advelvet%3d18%26bot%3d1%2c+Unknown+Bot+(B8E4201CA3B8EDF5DEAEE8E277BFB3CD)%3amonitor%3aBrowser+Impersonator%26pgview%3d1%26partner%3daccuweather%26ufdb%3dSFOC%26city%3dSan+Francisco%26country%3dUS%26state%3dCA%26dma%3d807%26key%3d347629%26zip%3d941XX%26browser%3dother%26connection%3d_vhigh_5000%26wx_seg%3d101105100%2c101101104%2c100109104%2c104100104%2c100112103%2c108102100%2c100111101%2c101104101%2c110100100%2c109101100%2c102101100%2c102102100%2c108105100%2c101103100%2c102100100%2c108103102%2c100108101%2c101108100%2c102103102%2c100113105%2c100109107%2c100100%2c101102101%2c101106101%2c100106103%2c110101102%2c109105103%2c109104103%2c101100100%2c108100104%2c101107100%2c109102104%2c103100104%2c109106104%2c108101104%2c107100103%2c999100001%2c102104100%2c105100104%2c109103104%2c104101104%2c103101104%2c107101103%2c109100104%2c108104101%26alertscategory%3dNON-PRECIPITATION%26alertssource%3dUS%26alertstypeid%3dUS12%26cuhd%3d69%26cuhi%3d61%26cuuv%3d8%26cuwd%3d6%26cuwx%3d3%26realfeel%3d70%2ca70%26fc1hi%3d65%26fc1lo%3d55%26fc1wx%3d2%26lfscategory%3dfog%26lfsday%3d2%26lfsseverity%3d5%26lfs%3d5_fog_2%26pt%3d0%26userid%3dactive%26userid3p%3dactive%26iabctax%3dIAB12-3%2cIAB15-10%2cIAB20-8%2c390%2c660&amp;ppid=65b9d07aa1864460b4887063841b629f&amp;userid3p=active"></script>
# <img alt="ComScore" src="https://sb.scorecardresearch.com/p?cs_fpid=65b9d07a-a186-4460-b488-7063841b629f&amp;cs_fpit=c&amp;c1=2&amp;c4=https%3a%2f%2fwww.accuweather.com%2fen%2fus%2fsan-francisco%2f94103%2fcurrent-weather%2f347629&amp;c2=6005068&amp;c7=https%3a%2f%2fwww.accuweather.com%2fen%2fus%2fsan-francisco%2f94103%2fcurrent-weather%2f347629&amp;c8=San%20Francisco%2C%20CA%20Current%20Weather%20%7C%20AccuWeather&amp;c9=&amp;cs_ucfr="/>
# <script>
# 	var isPushlyEnabled = true;
# </script>
# <script defer="" onerror="window.pushlyCallbackError=true;" src="https://cdn.p-n.io/pushly-sdk.min.js?domain_key=16if7iQ5tgH1FcRA4cUeejyVcdf5guIAEV9R"></script>
# <script>
# 		function callBlockthroughScript() {
# 			const scriptEl = document.getElementById('bt_bootstrap_2.0')
# 			if (!scriptEl) {
# 				const s = document.createElement("script");
# 				el = document.getElementsByTagName("script")[0];
# 				s.setAttribute('id', 'bt_bootstrap_2.0');
# 				s.async = true;
# 				s.src = "//accuweather-com.videoplayerhub.com/btTag.js?w=5760049299324928";
# 				el.parentNode.insertBefore(s, el);
# 			}
# 		};
# 		window.addEventListener('load', callBlockthroughScript);
#
# 			setTimeout(callBlockthroughScript, 15000);
# 				</script>
# <script>
# 	try {
# 		;
# 	} catch (error) {}
# 	</script>
# </body>
# </html>

# %%
# Using Tavily's Agentic Search

result = client.search(query, max_results=1)
data = result["results"][0]["content"]
print(data)
# Out:
# {'location': {'name': 'San Francisco', 'region': 'California', 'country': 'United States of America', 'lat': 37.78, 'lon': -122.42, 'tz_id': 'America/Los_Angeles', 'localtime_epoch': 1717696235, 'localtime': '2024-06-06 10:50'}, 'current': {'last_updated_epoch': 1717695900, 'last_updated': '2024-06-06 10:45', 'temp_c': 13.0, 'temp_f': 55.4, 'is_day': 1, 'condition': {'text': 'Mist', 'icon': '//cdn.weatherapi.com/weather/64x64/day/143.png', 'code': 1030}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1013.0, 'pressure_in': 29.92, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 94, 'cloud': 25, 'feelslike_c': 11.9, 'feelslike_f': 53.5, 'windchill_c': 14.4, 'windchill_f': 57.8, 'heatindex_c': 14.8, 'heatindex_f': 58.6, 'dewpoint_c': 10.2, 'dewpoint_f': 50.3, 'vis_km': 4.0, 'vis_miles': 2.0, 'uv': 4.0, 'gust_mph': 9.8, 'gust_kph': 15.7}}

# %%
import json
from pygments import formatters, highlight, lexers, formatters

parsed_json = json.loads(data.replace("'", '"'))
formatted_json = json.dumps(parsed_json, indent=4)
colourful_json = highlight(formatted_json, lexers.JsonLexer(), formatters.TerminalFormatter())
print(colourful_json)
# Out:
# {
#     "location": {
#         "name": "San Francisco",
#         "region": "California",
#         "country": "United States of America",
#         "lat": 37.78,
#         "lon": -122.42,
#         "tz_id": "America/Los_Angeles",
#         "localtime_epoch": 1717696235,
#         "localtime": "2024-06-06 10:50"
#     },
#     "current": {
#         "last_updated_epoch": 1717695900,
#         "last_updated": "2024-06-06 10:45",
#         "temp_c": 13.0,
#         "temp_f": 55.4,
#         "is_day": 1,
#         "condition": {
#             "text": "Mist",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/143.png",
#             "code": 1030
#         },
#         "wind_mph": 8.1,
#         "wind_kph": 13.0,
#         "wind_degree": 220,
#         "wind_dir": "SW",
#         "pressure_mb": 1013.0,
#         "pressure_in": 29.92,
#         "precip_mm": 0.0,
#         "precip_in": 0.0,
#         "humidity": 94,
#         "cloud": 25,
#         "feelslike_c": 11.9,
#         "feelslike_f": 53.5,
#         "windchill_c": 14.4,
#         "windchill_f": 57.8,
#         "heatindex_c": 14.8,
#         "heatindex_f": 58.6,
#         "dewpoint_c": 10.2,
#         "dewpoint_f": 50.3,
#         "vis_km": 4.0,
#         "vis_miles": 2.0,
#         "uv": 4.0,
#         "gust_mph": 9.8,
#         "gust_kph": 15.7
#     }
# }
